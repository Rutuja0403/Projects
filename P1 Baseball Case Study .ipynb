# %% [markdown]
# # Baseball Case Study

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of
# wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that
# will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# - Input features:
#     R: Runs, AB: At Bats, H: Hits, 2B: Doubles, 3B: Triples, HR: Homeruns, BB: Walks, SO: Strikeouts , SB: Stolen Bases,
#     RA: Runs Allowed, ER: Earned Runs, ERA: Earned Run Average (ERA), CG: Complete Games, SHO: Shutouts SV: Saves, E: Errors.
#
#
#
# - Output feature:
#     Number of predicted wins (W)

# %%
#Import the Data
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#Check the type of data set
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Check for the null values in data**

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - The data set has no null values present in any of the column, so no need to add any data

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# - The above dataset contains 30 rows and 17 columns.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### Check unique values

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# **Get some information about data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# - The data has no null values, from 17 columns present in data set 16 columns has int64 data type where 1column
#   which is ERA has float data type Hence the present data set is perfect set of data and no need of data conversion,
#   we can simply move forword with Visualization.

# %% [markdown]
#  ### Exploratory Data Analysis(EDA)

# %%
#Runs vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='R',y='W',data=df)
plt.xlabel('Run')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Runs and Win are linearly corelated.
# - And there is a outlier near 900

# %%
#AtBat vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='AB',y='W',data=df)
plt.xlabel('Atbat')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the AtBats is very weakly negativly related to win.
# - And there is no outliers present here.

# %%
#Hits vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='H',y='W',data=df)
plt.xlabel('Hits')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Hits is also very weakly related to win.
# - And there is no outliers present here.

# %%
#Doubles vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='2B',y='W',data=df)
plt.xlabel('Doubles(2B)')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Doubles is linearly related to win.
# - And there is no outliers present here.

# %%
#Triples vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='3B',y='W',data=df)
plt.xlabel('Triples')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Triples is having very weak negative correlation with win.
# - And there is no outliers present here.

# %%
#Homeruns vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='HR',y='W',data=df)
plt.xlabel('Homeruns')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the HomeRuns is having very low correlation with win.
# - And there is no outliers present here.

# %%
#Walks vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='BB',y='W',data=df)
plt.xlabel('Walks')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Walk is slightly corelated to win.
# - And there is no outliers present here.

# %%
#Strikeouts vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='SO',y='W',data=df)
plt.xlabel('Strikeouts')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the StrikOuts is not corelated to win.
# - And there is no outliers present here.

# %%
#StolenBases vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='SB',y='W',data=df)
plt.xlabel('StolenBases')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the StolenBases is negatively correlated to win.
# - And there is no outliers present here.

# %%
#RunsAllowed vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='RA',y='W',data=df)
plt.xlabel('RunsAllowed')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the RunsAllowed is Highly negatively correlated to win.
# - And there is no outliers present here.

# %%
#EarnedRuns vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='ER',y='W',data=df)
plt.xlabel('EarnedRuns')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the EarnedRuns is Highly negatively correlated to win.
# - And there is no outliers present here.

# %%
#EarnedRunAvg vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='ERA',y='W',data=df)
plt.xlabel('EarnedRunAvg')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the ERA is Highly negatively correlated to win.
# - And there is outliers present here.

# %%
#CompleteGames vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='CG',y='W',data=df)
plt.xlabel('CompleteGames')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the CompleteGames is not related to win.
# - And there is no outliers present here.

# %%
#Shutouts vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='SHO',y='W',data=df)
plt.xlabel('Shutouts')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Shutouts corelated to win.
# - And there is outliers present here.

# %%
#Saves vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='SV',y='W',data=df)
plt.xlabel('Saves')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Saves are highly correlated to win.
# - And there is outliers present here.

# %%
#Errors vs Win
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.regplot(x='E',y='W',data=df)
plt.xlabel('Errors')
plt.ylabel('Win') 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - From the above graph we can see that the Errors are negatively correlated to win.
# - And there is outliers present here.

# %%
sns.pairplot(df)
plt.savefig('Pairplot.png')
plt.show()

# %% [markdown]
# **Correlation**

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# **Correlation Using HeatMap**

# %%
sns.heatmap(df.corr(), annot=True, fmt= '.2f')
plt.figure(figsize=(20,10))

# %% [markdown]
# ###  Checking the columns for the Positive and Negative correlation with Target   Variables

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# **Outcome of Correlation**

# %% [markdown]
# - Runs and Win are linearly corelated.
# - AtBats is very weakly negative correlated to win.
# - Hits is also very weakly related to win.
# - Doubles is linearly related to win.
# - Triples is having negative correlation with win.
# - HomeRuns is having very low correlation with win
# - Walk is slightly corelated to win.
# - StrikOuts is not corelated to win.
# - Stolenbases is negatively corelated to win.
# - RunsAllowed is Highly negatively correlated to win.
# - EarnedRuns is Highly negatively correlated to win.
# - ERA is Highly negatively correlated to win.
# - CompleteGames is not related to win.
# - Shutouts are corelated to win.
# - Savesare highly correlated to win.
# - Errors are negative correlated to win.

# %% [markdown]
# ### Describing Datasets:

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# - Lets Check with heat map

# %%
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=False,fmt="f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Outliers Checking

# %%
collist=df.columns.values
ncol=30
nrows=20

# %%
for i in range(1, len(collist)):
    print(collist[i])
    break
# Out:
# R

# %%
plt.figure(figsize=(ncol,4*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# - From the above plot we can see that        columns['Run','ERA','Shutouts','Saves','Errors'] has outliers,
#   where 'Errors' has more Outliers
# - All the remaining columns does not have Outliers

# %% [markdown]
# ### Checking Normal Distribution

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['R'])
plt.xlabel('Runs')
# Out:
# Text(0.5, 0, 'Runs')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve. and it is bimodal

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['AB'])
plt.xlabel('Atbats')
# Out:
# Text(0.5, 0, 'Atbats')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['H'])
plt.xlabel('Hits')
# Out:
# Text(0.5, 0, 'Hits')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve. and its almost bimodal

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['2B'])
plt.xlabel('Doubles')
# Out:
# Text(0.5, 0, 'Doubles')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['3B'])
plt.xlabel('Triples')
# Out:
# Text(0.5, 0, 'Triples')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['HR'])
plt.xlabel('Homeruns')
# Out:
# Text(0.5, 0, 'Homeruns')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['BB'])
plt.xlabel('Walks')
# Out:
# Text(0.5, 0, 'Walks')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['SO'])
plt.xlabel('Strikeouts')
# Out:
# Text(0.5, 0, 'Strikeouts')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['SB'])
plt.xlabel('StolenBases')
# Out:
# Text(0.5, 0, 'StolenBases')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['RA'])
plt.xlabel('RunsAllowed')
# Out:
# Text(0.5, 0, 'RunsAllowed')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['ER'])
plt.xlabel('EarnedRuns')
# Out:
# Text(0.5, 0, 'EarnedRuns')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['ERA'])
plt.xlabel('EarnedRunAvg')
# Out:
# Text(0.5, 0, 'EarnedRunAvg')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['CG'])
plt.xlabel('CompleteGame')
# Out:
# Text(0.5, 0, 'CompleteGame')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['SHO'])
plt.xlabel('Shutouts')
# Out:
# Text(0.5, 0, 'Shutouts')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['SV'])
plt.xlabel('Saves')
# Out:
# Text(0.5, 0, 'Saves')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.distplot(df['E'])
plt.xlabel('Errors')
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# - The data of the column is not normalised and the building blocks is out of the normalised curve.

# %% [markdown]
# ### Skewness Checking

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# ### Preprocessing

# %%
#Remove Outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (29, 17)

# %%
print("old DataFrame", df.shape)
print("new DataFrame", df_new.shape)
print("dropped rows",df.shape[0]-df_new.shape[0])
# Out:
# old DataFrame (30, 17)
# new DataFrame (29, 17)
# dropped rows 1

# %%
loss_percent=(30-29)/30*100
print(loss_percent,'%')
# Out:
# 3.3333333333333335 %

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# ### Remove Skewness

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %%
from sklearn.preprocessing import power_transform, PowerTransformer

# %%
PowerTransformer()
# Out:
# PowerTransformer()

# %%
x_new=power_transform(x)

# %%
x_new
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
#Checking skewness
pd.DataFrame(x_new, columns = x.columns).skew().sort_values(ascending=False)
# Out:
# E      0.065585
# SO     0.051530
# SHO    0.000529
# HR     0.000448
# AB     0.000000
# H      0.000000
# ERA   -0.000401
# SV    -0.000925
# ER    -0.004988
# BB    -0.008572
# SB    -0.009570
# RA    -0.011974
# R     -0.024842
# CG    -0.045947
# 2B    -0.052793
# 3B    -0.075139
# dtype: float64

# %% [markdown]
# - range is 0.06 to -0.07 which is exceptable

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
x=pd.DataFrame(x_new, columns=x.columns)

# %%
x.skew().sort_values(ascending=False)
# Out:
# E      0.065585
# SO     0.051530
# SHO    0.000529
# HR     0.000448
# AB     0.000000
# H      0.000000
# ERA   -0.000401
# SV    -0.000925
# ER    -0.004988
# BB    -0.008572
# SB    -0.009570
# RA    -0.011974
# R     -0.024842
# CG    -0.045947
# 2B    -0.052793
# 3B    -0.075139
# dtype: float64

# %% [markdown]
# - Skewness has been removed so we can move forword

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y , test_size = 0.2, random_state = 20)

# %%
lr = LinearRegression( fit_intercept = True)
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Linear coefficients : {lr.coef_}")
print(f"Intercept : {lr.intercept_}")
# Out:
# Linear coefficients : [ 4.51502757e+00 -3.11972670e-14  5.01820807e-14 -2.11996330e+00
#   1.24821319e+00  8.42988206e-01 -8.14628111e-01 -2.42852829e+00
#  -3.04814507e-01  1.17089541e+01 -1.29965807e+01 -6.60380184e+00
#   1.33792706e+00  1.78650997e+00  3.21086939e+00  1.55445870e+00]
# Intercept : 80.5960789112806

# %%
y_pred = lr.predict(x_test)

# %% [markdown]
# ### RMSE

# %%
from sklearn import metrics 
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error: 6.78494367726059

# %% [markdown]
# ### R-Squared

# %%
lrs=r2_score(y_test, y_pred)
print('R2 Score:',lrs*100)
# Out:
# R2 Score: 1.6453065086323604

# %%
from sklearn.model_selection import cross_val_score
lrscore = cross_val_score(lr, x, y, cv=5)
lrc = lrscore.mean()
print('Cross val score :', lrc*100 )
# Out:
# Cross val score : 37.61324121236934

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=y_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual win', fontsize=14)
plt.ylabel('Predicted win', fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# ### RandomForest Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],
              'max_features':["auto", "sqrt", "log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train, y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mae", max_features="auto")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
y_pred = rf.predict(x_test)

rfs = r2_score(y_test, y_pred)
print('R2 Score:',lrs*100)

rfscore = cross_val_score(rf, x, y, cv=5)
rfc = rfscore.mean()
print('Cross val score :', rfc*100 )
# Out:
# R2 Score: 1.6453065086323604
# Cross val score : -58.33392737622424

# %%
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_friedman1
from sklearn.ensemble import GradientBoostingRegressor

x, y = make_friedman1(n_samples=1200, random_state=0, noise=1.0)
x_train, x_test = x[:200], x[200:]
y_train, y_test = y[:200], y[200:]
est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1,max_depth=1, random_state=0,
                                loss='squared_error').fit(x_train, y_train)
mean_squared_error(y_test, est.predict(x_test))
# Out:
# 5.009154859960321

# %% [markdown]
# ### Regularization

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],
             'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
#model training
ls = Lasso(alpha=0.01,random_state=0)
ls.fit(x_train,y_train)
ls_score_training = ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)
ls_score_training*100
# Out:
# 71.37804963414543

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 74.58420785115423

# %%
import pickle
filename = 'wins.pkl'
pickle.dump(ls,open(filename, 'wb'))

# %%
import statsmodels.api as sm

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     360.3
# Date:                Mon, 19 Sep 2022   Prob (F-statistic):               0.00
# Time:                        19:55:04   Log-Likelihood:                -2828.8
# No. Observations:                1200   AIC:                             5680.
# Df Residuals:                    1189   BIC:                             5736.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6102      0.409      1.490      0.136      -0.193       1.414
# ...
